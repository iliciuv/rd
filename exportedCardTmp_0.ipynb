# %%
########### ARDL COINTEGRATION BPCGM ESTIMATION #############
relpath <- "/home/other/Desktop/ARDL.sept2020/"
source("/home/other/Desktop/ARDL.sept2020/API/rdbenomicsL.FULL.R")
options(warn = -1)
library("systemfit")
library("ARDL")
library("dLagM")
break_m <- c(0, 0, 15, 0, 0, 15, 0, 15, 8, 0, 15)
break_m1 <- c(0, 0, 0, 0, 0, 20, 0, 20, 0, 0, 20)
bp_exp <- data.frame(matrix(NA, 2, 11))
bp_imp <- data.frame(matrix(NA, 2, 11))
p_test_mf <- data.frame(matrix(NA, 11, 3))
p_test_xf <- data.frame(matrix(NA, 11, 3))
ardl_fx <- array()
ardl_fm <- array()
ardl_fx1 <- array()
ardl_fm1 <- array()
coeff_x <- data.frame(matrix(NA, 10, 11))
coeff_m <- data.frame(matrix(NA, 18, 11))
break_m <- c(rep(15, 11))
rows_x <- c(
  "intercept", "finco", "rpri", "ect",
  "tsat", "tstat", "tstat", "tsat", "FboundX", "FpvalueX"
)
rows_m <- c(
  "intercept", "inco", "rpri", "dum", "dum2", "dum3", "dum4", "ect", "tstat",
  "tsat", "tstat", "tstat", "tstat", "tstat", "tstat", "tstat", "FboundM", "FpvalueM"
)

for (i in seq_along(Countries)) {
  if (i == 1 | i == 2 | i == 4 | i == 5 | i == 7 | i == 10) {
    source(paste0(relpath, "/MODELS/FORMULA/NODUMnew.R"))
    source(paste0(relpath, "/MODELS/FORMULA/NODUM.R"))

  }
  if (i == 6 | i == 8 | i == 11 | i == 9 | i == 3) {
    source(paste0(relpath, "/MODELS/FORMULA/DUMnew.R"))
    source(paste0(relpath, "/MODELS/FORMULA/DUM.R"))
  }
}

ardl_ftest <- cbind(ardl_fx, ardl_fx1, p_test_xf, ardl_fm, ardl_fm1, p_test_mf)
show(ardl_ftest)
# Out:
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.55836, df1 = 1, df2 = 16, p-value = 0.4658
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.20621, df = 1, p-value = 0.6498
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 7.9472, df = 7, p-value = 0.3373
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96239, p-value = 0.4641
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.80651518350978
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 3.6985, df1 = 2, df2 = 18, p-value = 0.04512
#
# the p-value of RESET test:  0.04512285 < 0.05!
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.030790 -0.020747  0.001245  0.017325  0.041861
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0006660  0.0006576   1.013    0.323
# dfinco.t  3.0365070  0.3038632   9.993  3.2e-09 ***
# dfinco.1 -0.6147950  0.7260642  -0.847    0.407
# drpri.t  -0.0221690  0.2032661  -0.109    0.914
# dexpo.1   0.0300881  0.2182179   0.138    0.892
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02271 on 20 degrees of freedom
# Multiple R-squared:  0.9174,	Adjusted R-squared:  0.8967
# F-statistic:  44.4 on 5 and 20 DF,  p-value: 3.749e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.2993073  0.9543554 -0.1217201
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.35075, df1 = 1, df2 = 17, p-value = 0.5615
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.20483, df = 1, p-value = 0.6509
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 9.2351, df = 6, p-value = 0.1608
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98402, p-value = 0.9515
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.15214182378303
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.24602, df1 = 2, df2 = 19, p-value = 0.7844
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.040647 -0.009888  0.010107  0.015152  0.045698
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.06304    0.06049  -1.042  0.30922
# dinco.t  2.78610    0.21962  12.686 2.59e-11 ***
# drpri.t  0.19358    0.19048   1.016  0.32106
# dimpo.1 -0.29875    0.09218  -3.241  0.00391 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02096 on 21 degrees of freedom
# Multiple R-squared:  0.9004,	Adjusted R-squared:  0.8814
# F-statistic: 47.45 on 4 and 21 DF,  p-value: 3.178e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1
# -0.6265007  1.2957493  0.2320143
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 1.1938, df1 = 1, df2 = 17, p-value = 0.2898
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.74078, df = 1, p-value = 0.3894
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 8.5729, df = 6, p-value = 0.1991
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.94805, p-value = 0.2265
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.31200544176792
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.96323, df1 = 2, df2 = 19, p-value = 0.3995
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0256079 -0.0156603 -0.0005384  0.0137967  0.0257215
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0016699  0.0007755   2.153 0.043056 *
# dfinco.t  2.5319442  0.2195681  11.531 1.51e-10 ***
# drpri.t   0.0795925  0.0710006   1.121 0.274940
# dexpo.1  -0.3129618  0.0799274  -3.916 0.000795 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01734 on 21 degrees of freedom
# Multiple R-squared:  0.9282,	Adjusted R-squared:  0.9146
# F-statistic: 67.91 on 4 and 21 DF,  p-value: 1.043e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
# -0.12337471  0.27064036  0.04331361
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.17348, df1 = 1, df2 = 16, p-value = 0.6826
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.09319, df = 1, p-value = 0.7602
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.7303, df = 7, p-value = 0.8103
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98117, p-value = 0.9074
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.66970079305533
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.61879, df1 = 2, df2 = 18, p-value = 0.5497
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034537 -0.005497  0.005323  0.009693  0.031060
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.5897     0.1180  -4.997 6.91e-05 ***
# dinco.t   2.7726     0.2395  11.575 2.56e-10 ***
# dinco.1   2.0351     0.4635   4.390 0.000282 ***
# drpri.t  -0.1010     0.0753  -1.342 0.194744
# dimpo.1  -0.4037     0.1449  -2.786 0.011415 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01728 on 20 degrees of freedom
# Multiple R-squared:  0.9308,	Adjusted R-squared:  0.9134
# F-statistic: 53.77 on 5 and 20 DF,  p-value: 6.518e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1
# -0.67916110  1.34273575  0.02459904
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.068633, df1 = 1, df2 = 14, p-value = 0.7972
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.09398, df = 1, p-value = 0.7592
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.1331, df = 8, p-value = 0.7433
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96891, p-value = 0.6402
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.93478950110739
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 2.3996, df1 = 2, df2 = 16, p-value = 0.1226
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 3, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.050931 -0.014840  0.004419  0.015862  0.063209
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.0014390  0.0005868  -2.452   0.0246 *
# dfinco.t  3.7062599  0.3973964   9.326 2.58e-08 ***
# drpri.t   0.2122157  0.2487671   0.853   0.4048
# drpri.1   0.4181370  0.2137604   1.956   0.0662 .
# dexpo.1  -0.0168852  0.0982066  -0.172   0.8654
# dexpo.2   0.2229685  0.0977820   2.280   0.0350 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03149 on 18 degrees of freedom
# Multiple R-squared:  0.8924,	Adjusted R-squared:  0.8565
# F-statistic: 24.87 on 6 and 18 DF,  p-value: 8.703e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.0730141  0.3303639 -0.8842444
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 1.3486, df1 = 1, df2 = 15, p-value = 0.2637
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.73059, df = 1, p-value = 0.3927
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.3693, df = 8, p-value = 0.9091
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.91476, p-value = 0.03898
#
# The p-value of Shapiro-Wilk test normality of residuals:  0.03897535 < 0.05!
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.81415337099871
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.152, df1 = 2, df2 = 18, p-value = 0.3382
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.045766 -0.008150 -0.001615  0.010766  0.049762
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.01260    0.01711  -0.736   0.4702
# dinco.t  1.88296    0.17312  10.877 7.56e-10 ***
# drpri.t  0.18769    0.16177   1.160   0.2596
# ddum.t  -0.03022    0.02529  -1.195   0.2462
# ddum.1   0.06249    0.02537   2.464   0.0229 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02423 on 20 degrees of freedom
# Multiple R-squared:  0.9227,	Adjusted R-squared:  0.9034
# F-statistic: 47.76 on 5 and 20 DF,  p-value: 1.931e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.79325703  1.42615987  0.53621547  0.09535141
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.10244, df1 = 1, df2 = 17, p-value = 0.7528
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.10287, df = 1, p-value = 0.7484
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.766, df = 6, p-value = 0.4499
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.93073, p-value = 0.09035
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.25054652227515
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.1804, df1 = 2, df2 = 19, p-value = 0.3287
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.042852 -0.015443 -0.004394  0.016695  0.059431
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0009724  0.0027351   0.356    0.726
# dfinco.t  2.5650030  0.3633964   7.058 5.77e-07 ***
# drpri.t   0.0341202  0.1382379   0.247    0.807
# dexpo.1  -0.0644002  0.1174693  -0.548    0.589
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02616 on 21 degrees of freedom
# Multiple R-squared:  0.8496,	Adjusted R-squared:  0.821
# F-statistic: 29.66 on 4 and 21 DF,  p-value: 2.274e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.2090581  0.3885582  0.1289411
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.0040899, df1 = 1, df2 = 17, p-value = 0.9498
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.0034063, df = 1, p-value = 0.9535
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 10.2, df = 6, p-value = 0.1165
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96013, p-value = 0.417
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.30160129045968
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.95842, df1 = 2, df2 = 19, p-value = 0.4013
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0279784 -0.0128314  0.0007527  0.0132237  0.0294333
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.05540    0.07302  -0.759   0.4564
# dinco.t  3.33137    0.25213  13.213 1.21e-11 ***
# drpri.t  0.19410    0.08469   2.292   0.0324 *
# dimpo.1 -0.15093    0.08039  -1.877   0.0744 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01717 on 21 degrees of freedom
# Multiple R-squared:  0.938,	Adjusted R-squared:  0.9262
# F-statistic: 79.43 on 4 and 21 DF,  p-value: 2.267e-12
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1
# -0.4792890  1.2355419  0.1143074
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 2.3143, df1 = 1, df2 = 16, p-value = 0.1477
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 1.599, df = 1, p-value = 0.2061
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.9369, df = 7, p-value = 0.787
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.94159, p-value = 0.1611
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.53251245034975
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.0244, df1 = 2, df2 = 18, p-value = 0.379
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.036954 -0.014765 -0.000274  0.010039  0.041979
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1      0.002521   0.001305   1.933   0.0676 .
# dfinco.t  3.063880   0.280789  10.912 7.15e-10 ***
# dfinco.1 -1.308244   0.701000  -1.866   0.0767 .
# drpri.t  -0.169904   0.172289  -0.986   0.3358
# dexpo.1   0.242605   0.196657   1.234   0.2316
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02246 on 20 degrees of freedom
# Multiple R-squared:  0.9333,	Adjusted R-squared:  0.9166
# F-statistic: 55.94 on 5 and 20 DF,  p-value: 4.527e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.1918277  0.7043635  0.0917034
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 2.1113, df1 = 1, df2 = 16, p-value = 0.1655
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 1.7726, df = 1, p-value = 0.1831
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 10.9, df = 7, p-value = 0.143
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.94732, p-value = 0.218
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 6.78856553805687
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.53989, df1 = 2, df2 = 18, p-value = 0.592
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.041514 -0.006168  0.004075  0.014441  0.045614
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.06400    0.01375  -4.655 0.000153 ***
# dinco.t  1.95313    0.22390   8.723 2.99e-08 ***
# dinco.1 -1.15959    0.40302  -2.877 0.009315 **
# drpri.t  0.05832    0.15332   0.380 0.707679
# dimpo.1  0.30538    0.15260   2.001 0.059123 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02068 on 20 degrees of freedom
# Multiple R-squared:  0.9257,	Adjusted R-squared:  0.9072
# F-statistic: 49.86 on 5 and 20 DF,  p-value: 1.305e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1
# -0.06326806  0.09989207 -0.24148992
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.41194, df1 = 1, df2 = 17, p-value = 0.5295
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.27201, df = 1, p-value = 0.602
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 6.1358, df = 6, p-value = 0.4081
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.95862, p-value = 0.3876
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.98589803968444
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 2.7501, df1 = 2, df2 = 19, p-value = 0.08934
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.10315 -0.03041 -0.01252  0.03158  0.11894
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.001687   0.001747  -0.966    0.345
# dfinco.t  4.220611   0.789806   5.344 2.67e-05 ***
# drpri.t  -0.159872   0.163596  -0.977    0.340
# dexpo.1  -0.016293   0.145165  -0.112    0.912
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06196 on 21 degrees of freedom
# Multiple R-squared:  0.6815,	Adjusted R-squared:  0.6209
# F-statistic: 11.23 on 4 and 21 DF,  p-value: 4.942e-05
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.4592267  1.2093168  0.2198231
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.029834, df1 = 1, df2 = 15, p-value = 0.8652
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.034186, df = 1, p-value = 0.8533
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 7.3931, df = 8, p-value = 0.4949
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.97631, p-value = 0.8037
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.41312371695516
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.43443, df1 = 2, df2 = 18, p-value = 0.6542
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.177492 -0.019010  0.005086  0.032762  0.101743
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.017887   0.013870  -1.290    0.212
# dinco.t  1.640131   0.320813   5.112 5.31e-05 ***
# drpri.t  0.139298   0.164589   0.846    0.407
# ddum.t   0.068986   0.066536   1.037    0.312
# ddum.1  -0.003874   0.066096  -0.059    0.954
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06432 on 20 degrees of freedom
# Multiple R-squared:  0.6439,	Adjusted R-squared:  0.5548
# F-statistic: 7.231 on 5 and 20 DF,  p-value: 0.0005183
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.30065999  0.18099594  0.42449217  0.05898003
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.018602, df1 = 1, df2 = 17, p-value = 0.8931
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.0060276, df = 1, p-value = 0.9381
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.6093, df = 6, p-value = 0.7294
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.86321, p-value = 0.003171
#
# The p-value of Shapiro-Wilk test normality of residuals:  0.003170772 < 0.05!
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.47517107283528
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 3.1046, df1 = 2, df2 = 19, p-value = 0.06813
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.093830 -0.047980 -0.008719  0.020287  0.197628
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0010422  0.0004267   2.443   0.0235 *
# dfinco.t  1.7394875  0.9269348   1.877   0.0745 .
# drpri.t  -0.4699181  0.2435175  -1.930   0.0673 .
# dexpo.1   0.1328554  0.1903638   0.698   0.4929
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0669 on 21 degrees of freedom
# Multiple R-squared:  0.7581,	Adjusted R-squared:  0.712
# F-statistic: 16.45 on 4 and 21 DF,  p-value: 3.025e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
#  0.01872390 -0.22924650 -0.05144336
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.31997, df1 = 1, df2 = 13, p-value = 0.5813
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.16205, df = 1, p-value = 0.6873
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.3007, df = 8, p-value = 0.725
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98316, p-value = 0.9523
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 4.57517592908376
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 4.5726, df1 = 2, df2 = 15, p-value = 0.02815
#
# the p-value of RESET test:  0.02814895 < 0.05!
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 4, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.091060 -0.008626  0.007449  0.041636  0.083492
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.14605    0.09268  -1.576 0.133472
# dinco.t  1.06326    0.21137   5.030 0.000103 ***
# drpri.t -0.46706    0.29844  -1.565 0.136008
# dimpo.1  0.49309    0.16486   2.991 0.008209 **
# dimpo.2 -0.22219    0.19814  -1.121 0.277718
# dimpo.3 -0.02292    0.15909  -0.144 0.887127
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05194 on 17 degrees of freedom
# Multiple R-squared:  0.8619,	Adjusted R-squared:  0.8132
# F-statistic: 17.69 on 6 and 17 DF,  p-value: 1.881e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1
# -0.4569612  0.6950902 -0.3474241
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.53873, df1 = 1, df2 = 14, p-value = 0.4751
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.57679, df = 1, p-value = 0.4476
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 10.782, df = 8, p-value = 0.2144
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.95062, p-value = 0.2794
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 9.43772674116529
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 2.9932, df1 = 2, df2 = 16, p-value = 0.07865
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 3, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.045745 -0.017011 -0.003753  0.009345  0.070336
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.0008107  0.0025193  -0.322   0.7513
# dfinco.t  3.6187524  0.4533539   7.982 2.53e-07 ***
# dfinco.1 -2.0860134  0.7576708  -2.753   0.0131 *
# drpri.t  -0.2567201  0.3408929  -0.753   0.4611
# dexpo.1   0.3158563  0.2017574   1.566   0.1349
# dexpo.2   0.0108597  0.1092339   0.099   0.9219
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03079 on 18 degrees of freedom
# Multiple R-squared:  0.8393,	Adjusted R-squared:  0.7857
# F-statistic: 15.66 on 6 and 18 DF,  p-value: 2.884e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -1.0757805  2.1953147 -0.7648106
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.011634, df1 = 1, df2 = 14, p-value = 0.9156
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.01464, df = 1, p-value = 0.9037
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.0793, df = 9, p-value = 0.8273
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.93303, p-value = 0.1021
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.595660266867
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.16539, df1 = 2, df2 = 17, p-value = 0.8489
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.050679 -0.013079 -0.000971  0.013677  0.047045
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.010026   0.004853  -2.066   0.0527 .
# dinco.t  2.765774   0.290322   9.527 1.14e-08 ***
# drpri.t  0.227375   0.238514   0.953   0.3524
# drpri.1 -0.375594   0.214926  -1.748   0.0967 .
# ddum.t   0.014630   0.026992   0.542   0.5941
# ddum.1  -0.039809   0.026499  -1.502   0.1495
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02444 on 19 degrees of freedom
# Multiple R-squared:  0.8953,	Adjusted R-squared:  0.8623
# F-statistic: 27.09 on 6 and 19 DF,  p-value: 2.414e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.33551110  1.18010435 -0.25286394  0.07132027
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.052437, df1 = 1, df2 = 16, p-value = 0.8218
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.06662, df = 1, p-value = 0.7963
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.9065, df = 7, p-value = 0.5507
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96176, p-value = 0.4506
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.36112190216361
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.6119, df1 = 2, df2 = 18, p-value = 0.227
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034820 -0.011315  0.002573  0.011126  0.034232
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1      0.008393   0.002484   3.378  0.00299 **
# dfinco.t  2.325115   0.260600   8.922 2.08e-08 ***
# drpri.t   0.170780   0.155648   1.097  0.28558
# drpri.1   0.217266   0.163272   1.331  0.19826
# dexpo.1  -0.237810   0.105669  -2.251  0.03583 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02032 on 20 degrees of freedom
# Multiple R-squared:  0.9187,	Adjusted R-squared:  0.8983
# F-statistic: 45.18 on 5 and 20 DF,  p-value: 3.206e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
# -0.03057827  0.04009441 -0.10824942
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 6.198, df1 = 1, df2 = 13, p-value = 0.02712
#
# The p-value of Breusch-Godfrey test for the autocorrelation in residuals:  0.02711615 < 0.05!
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 4.4744, df = 1, p-value = 0.03441
#
# The p-value of Ljung-Box test for the autocorrelation in residuals:  0.03440689 < 0.05!
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 16.831, df = 10, p-value = 0.07819
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.95745, p-value = 0.366
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.2263760815202
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.28341, df1 = 2, df2 = 16, p-value = 0.7569
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.071072 -0.008487 -0.003797  0.004427  0.083990
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.0175843  0.0083858  -2.097   0.0504 .
# dinco.t  2.1721076  0.3853748   5.636 2.39e-05 ***
# dinco.1 -0.7393703  0.3997237  -1.850   0.0808 .
# drpri.t -0.0163824  0.2582295  -0.063   0.9501
# drpri.1  0.0203725  0.3068428   0.066   0.9478
# ddum.t   0.0003541  0.0398629   0.009   0.9930
# ddum.1  -0.0491139  0.0335882  -1.462   0.1609
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03136 on 18 degrees of freedom
# Multiple R-squared:  0.847,	Adjusted R-squared:  0.7875
# F-statistic: 14.24 on 7 and 18 DF,  p-value: 3.596e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1      dum.1
# -0.3302606  0.5723346  0.3272584  0.0820918
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.0040176, df1 = 1, df2 = 16, p-value = 0.9502
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.0023628, df = 1, p-value = 0.9612
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.4294, df = 7, p-value = 0.8426
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96969, p-value = 0.6371
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.62013917674288
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.51092, df1 = 2, df2 = 18, p-value = 0.6084
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04134 -0.01041  0.00209  0.01099  0.06301
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0022602  0.0007897   2.862  0.00964 **
# dfinco.t  2.4054645  0.3283676   7.326 4.42e-07 ***
# dfinco.1 -1.3714366  0.4791514  -2.862  0.00963 **
# drpri.t  -0.4681398  0.2262060  -2.070  0.05166 .
# dexpo.1   0.2013032  0.1770576   1.137  0.26900
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02554 on 20 degrees of freedom
# Multiple R-squared:  0.8875,	Adjusted R-squared:  0.8594
# F-statistic: 31.55 on 5 and 20 DF,  p-value: 7.841e-09
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.1091053  0.3068078 -0.3181322
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.13596, df1 = 1, df2 = 16, p-value = 0.7172
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.12579, df = 1, p-value = 0.7228
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.5972, df = 7, p-value = 0.5875
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98348, p-value = 0.9442
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.32061386851097
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.1623, df1 = 2, df2 = 18, p-value = 0.8514
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.043170 -0.011964  0.001747  0.012805  0.035821
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.032957   0.009435  -3.493 0.002292 **
# dinco.t  2.827628   0.273347  10.344 1.78e-09 ***
# dinco.1 -1.647381   0.366958  -4.489 0.000224 ***
# drpri.t -0.296661   0.198192  -1.497 0.150052
# dimpo.1  0.176827   0.138946   1.273 0.217745
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02058 on 20 degrees of freedom
# Multiple R-squared:  0.9316,	Adjusted R-squared:  0.9145
# F-statistic: 54.49 on 5 and 20 DF,  p-value: 5.763e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1
# -0.04687273  0.10849520 -0.27414660
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.14889, df1 = 1, df2 = 16, p-value = 0.7047
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.058899, df = 1, p-value = 0.8082
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 6.1232, df = 7, p-value = 0.5254
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96289, p-value = 0.4751
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.08057552796928
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.21718, df1 = 2, df2 = 18, p-value = 0.8069
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03513 -0.01657  0.00170  0.01284  0.03669
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1      0.003347   0.002104   1.591 0.127301
# dfinco.t  2.420066   0.319948   7.564 2.74e-07 ***
# dfinco.1 -2.101528   0.398973  -5.267 3.73e-05 ***
# drpri.t   0.013296   0.162952   0.082 0.935781
# dexpo.1   0.592136   0.134000   4.419 0.000264 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02288 on 20 degrees of freedom
# Multiple R-squared:  0.9209,	Adjusted R-squared:  0.9011
# F-statistic: 46.55 on 5 and 20 DF,  p-value: 2.44e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
# -0.11826536  0.19257822 -0.08428204
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 1.1484, df1 = 1, df2 = 13, p-value = 0.3034
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 1.3734, df = 1, p-value = 0.2412
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.8918, df = 10, p-value = 0.8243
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.97772, p-value = 0.8365
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.92520381373836
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 3.5967, df1 = 2, df2 = 16, p-value = 0.05129
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07258 -0.01098  0.00000  0.01995  0.03346
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1     0.001542   0.013879   0.111 0.912763
# dinco.t  3.714349   0.417723   8.892 5.27e-08 ***
# dinco.1 -2.302709   0.526016  -4.378 0.000363 ***
# drpri.t -0.117690   0.222333  -0.529 0.603038
# ddum.t   0.022974   0.030875   0.744 0.466417
# ddum.1  -0.033274   0.030469  -1.092 0.289207
# dimpo.1  0.253572   0.143997   1.761 0.095224 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02848 on 18 degrees of freedom
# Multiple R-squared:  0.9189,	Adjusted R-squared:  0.8874
# F-statistic: 29.15 on 7 and 18 DF,  p-value: 1.42e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.40327445  0.90419188  0.05643735 -0.05254866
#
#     ardl_fx ardl_fx1 X1 X2 X3  ardl_fm  ardl_fm1 X1 X2 X3
# 1  1.806515 1.642668  1  1  0 2.152142 1.3252669  1  0  0
# 2  1.312005 1.168245  1  0  0 3.669701 1.2891705  1  1  0
# 3  2.934790 2.934790  2  0  1 2.814153 0.3775809  0  0  0
# 4  3.250547 1.779624  1  0  0 2.301601 3.2505465  1  0  0
# 5  2.532512 2.536138  1  1  0 6.788566 2.5325125  1  1  0
# 6  1.985898 1.985898  1  0  0 2.413124 2.7224007  0  0  0
# 7  1.475171 1.281960  1  0  0 4.575176 1.0299834  3  0  0
# 8  9.437727 9.437727  2  1  0 2.595660 6.3539250  0  0  1
# 9  3.361122 3.361122  1  0  1 2.226376 5.8486318  0  1  1
# 10 2.620139 2.464938  1  1  0 3.320614 2.6201392  1  1  0
# 11 2.080576 2.080576  1  1  0 2.925204 4.4821140  1  1  0

# %%
########### ARDL COINTEGRATION BPCGM ESTIMATION #############
relpath <- "/home/other/Desktop/ARDL.sept2020/"
source("/home/other/Desktop/ARDL.sept2020/API/rdbenomicsL.FULL.R")
options(warn = -1)
library("systemfit")
library("ARDL")
library("dLagM")
break_m <- c(0, 0, 15, 0, 0, 15, 0, 15, 8, 0, 15)
break_m1 <- c(0, 0, 0, 0, 0, 20, 0, 20, 0, 0, 20)
bp_exp <- data.frame(matrix(NA, 2, 11))
bp_imp <- data.frame(matrix(NA, 2, 11))
p_test_mf <- data.frame(matrix(NA, 11, 3))
p_test_xf <- data.frame(matrix(NA, 11, 3))
ardl_fx <- array()
ardl_fm <- array()
ardl_fx1 <- array()
ardl_fm1 <- array()
coeff_x <- data.frame(matrix(NA, 10, 11))
coeff_m <- data.frame(matrix(NA, 18, 11))
break_m <- c(rep(15, 11))
rows_x <- c(
  "intercept", "finco", "rpri", "ect",
  "tsat", "tstat", "tstat", "tsat", "FboundX", "FpvalueX"
)
rows_m <- c(
  "intercept", "inco", "rpri", "dum", "dum2", "dum3", "dum4", "ect", "tstat",
  "tsat", "tstat", "tstat", "tstat", "tstat", "tstat", "tstat", "FboundM", "FpvalueM"
)

for (i in seq_along(Countries)) {
  if (i == 1 | i == 2 | i == 4 | i == 5 | i == 7 | i == 10) {
    source(paste0(relpath, "/MODELS/FORMULA/NODUMnew.R"))
    source(paste0(relpath, "/MODELS/FORMULA/NODUM.R"))

  }
  if (i == 6 | i == 8 | i == 11 | i == 9 | i == 3) {
    source(paste0(relpath, "/MODELS/FORMULA/DUMnew.R"))
    source(paste0(relpath, "/MODELS/FORMULA/DUM.R"))
  }
}

ardl_ftest <- cbind(ardl_fx, ardl_fx1, p_test_xf, ardl_fm, ardl_fm1, p_test_mf)
show(ardl_ftest)
# Out:
# cointReg (v0.2.0): Parameter Estimation and Inference in a Cointegrating Regression.
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Visit <https://db.nomics.world>.
#
# Warning message in cbind(gdp$original_period, gdp$Country, gdp$value, inf$value, :
# “number of rows of result is not a multiple of vector length (arg 9)”
# Warning message in if (reorder) ugroup <- sort(ugroup, na.last = TRUE, method = "quick"):
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (reorder) ugroup <- sort(ugroup, na.last = TRUE, method = "quick"):
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (reorder) ugroup <- sort(ugroup, na.last = TRUE, method = "quick"):
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (reorder) ugroup <- sort(ugroup, na.last = TRUE, method = "quick"):
# “the condition has length > 1 and only the first element will be used”
# Loading required package: Matrix
#
# Loading required package: car
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# Loading required package: lmtest
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Please cite the 'systemfit' package as:
# Arne Henningsen and Jeff D. Hamann (2007). systemfit: A Package for Estimating Systems of Simultaneous Equations in R. Journal of Statistical Software 23(4), 1-40. http://www.jstatsoft.org/v23/i04/.
#
# If you have questions, suggestions, or comments regarding the 'systemfit' package, please use a forum or 'tracker' at systemfit's R-Forge site:
# https://r-forge.r-project.org/projects/systemfit/
#
# To cite ARDL in publications use:
#
# Kleanthis Natsiopoulos and Nickolaos Tzeremes (2020). ARDL: ARDL, ECM and Bounds-Test for Cointegration. R package version 0.1.0. University of Thessaly, Department of Economics. https://github.com/Natsiopoulos/ARDL.
#
# Loading required package: nardl
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Loading required package: dynlm
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.55836, df1 = 1, df2 = 16, p-value = 0.4658
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.20621, df = 1, p-value = 0.6498
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 7.9472, df = 7, p-value = 0.3373
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96239, p-value = 0.4641
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.80651518350978
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 3.6985, df1 = 2, df2 = 18, p-value = 0.04512
#
# the p-value of RESET test:  0.04512285 < 0.05!
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.030790 -0.020747  0.001245  0.017325  0.041861
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0006660  0.0006576   1.013    0.323
# dfinco.t  3.0365070  0.3038632   9.993  3.2e-09 ***
# dfinco.1 -0.6147950  0.7260642  -0.847    0.407
# drpri.t  -0.0221690  0.2032661  -0.109    0.914
# dexpo.1   0.0300881  0.2182179   0.138    0.892
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02271 on 20 degrees of freedom
# Multiple R-squared:  0.9174,	Adjusted R-squared:  0.8967
# F-statistic:  44.4 on 5 and 20 DF,  p-value: 3.749e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.2993073  0.9543554 -0.1217201
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.35075, df1 = 1, df2 = 17, p-value = 0.5615
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.20483, df = 1, p-value = 0.6509
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 9.2351, df = 6, p-value = 0.1608
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98402, p-value = 0.9515
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.15214182378303
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.24602, df1 = 2, df2 = 19, p-value = 0.7844
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.040647 -0.009888  0.010107  0.015152  0.045698
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.06304    0.06049  -1.042  0.30922
# dinco.t  2.78610    0.21962  12.686 2.59e-11 ***
# drpri.t  0.19358    0.19048   1.016  0.32106
# dimpo.1 -0.29875    0.09218  -3.241  0.00391 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02096 on 21 degrees of freedom
# Multiple R-squared:  0.9004,	Adjusted R-squared:  0.8814
# F-statistic: 47.45 on 4 and 21 DF,  p-value: 3.178e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1
# -0.6265007  1.2957493  0.2320143
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 1.1938, df1 = 1, df2 = 17, p-value = 0.2898
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.74078, df = 1, p-value = 0.3894
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 8.5729, df = 6, p-value = 0.1991
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.94805, p-value = 0.2265
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.31200544176792
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.96323, df1 = 2, df2 = 19, p-value = 0.3995
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0256079 -0.0156603 -0.0005384  0.0137967  0.0257215
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0016699  0.0007755   2.153 0.043056 *
# dfinco.t  2.5319442  0.2195681  11.531 1.51e-10 ***
# drpri.t   0.0795925  0.0710006   1.121 0.274940
# dexpo.1  -0.3129618  0.0799274  -3.916 0.000795 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01734 on 21 degrees of freedom
# Multiple R-squared:  0.9282,	Adjusted R-squared:  0.9146
# F-statistic: 67.91 on 4 and 21 DF,  p-value: 1.043e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
# -0.12337471  0.27064036  0.04331361
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.17348, df1 = 1, df2 = 16, p-value = 0.6826
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.09319, df = 1, p-value = 0.7602
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.7303, df = 7, p-value = 0.8103
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98117, p-value = 0.9074
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.66970079305533
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.61879, df1 = 2, df2 = 18, p-value = 0.5497
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034537 -0.005497  0.005323  0.009693  0.031060
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.5897     0.1180  -4.997 6.91e-05 ***
# dinco.t   2.7726     0.2395  11.575 2.56e-10 ***
# dinco.1   2.0351     0.4635   4.390 0.000282 ***
# drpri.t  -0.1010     0.0753  -1.342 0.194744
# dimpo.1  -0.4037     0.1449  -2.786 0.011415 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01728 on 20 degrees of freedom
# Multiple R-squared:  0.9308,	Adjusted R-squared:  0.9134
# F-statistic: 53.77 on 5 and 20 DF,  p-value: 6.518e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1
# -0.67916110  1.34273575  0.02459904
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.068633, df1 = 1, df2 = 14, p-value = 0.7972
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.09398, df = 1, p-value = 0.7592
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.1331, df = 8, p-value = 0.7433
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96891, p-value = 0.6402
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.93478950110739
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 2.3996, df1 = 2, df2 = 16, p-value = 0.1226
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 3, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.050931 -0.014840  0.004419  0.015862  0.063209
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.0014390  0.0005868  -2.452   0.0246 *
# dfinco.t  3.7062599  0.3973964   9.326 2.58e-08 ***
# drpri.t   0.2122157  0.2487671   0.853   0.4048
# drpri.1   0.4181370  0.2137604   1.956   0.0662 .
# dexpo.1  -0.0168852  0.0982066  -0.172   0.8654
# dexpo.2   0.2229685  0.0977820   2.280   0.0350 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03149 on 18 degrees of freedom
# Multiple R-squared:  0.8924,	Adjusted R-squared:  0.8565
# F-statistic: 24.87 on 6 and 18 DF,  p-value: 8.703e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.0730141  0.3303639 -0.8842444
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 1.3486, df1 = 1, df2 = 15, p-value = 0.2637
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.73059, df = 1, p-value = 0.3927
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.3693, df = 8, p-value = 0.9091
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.91476, p-value = 0.03898
#
# The p-value of Shapiro-Wilk test normality of residuals:  0.03897535 < 0.05!
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.81415337099871
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.152, df1 = 2, df2 = 18, p-value = 0.3382
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.045766 -0.008150 -0.001615  0.010766  0.049762
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.01260    0.01711  -0.736   0.4702
# dinco.t  1.88296    0.17312  10.877 7.56e-10 ***
# drpri.t  0.18769    0.16177   1.160   0.2596
# ddum.t  -0.03022    0.02529  -1.195   0.2462
# ddum.1   0.06249    0.02537   2.464   0.0229 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02423 on 20 degrees of freedom
# Multiple R-squared:  0.9227,	Adjusted R-squared:  0.9034
# F-statistic: 47.76 on 5 and 20 DF,  p-value: 1.931e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.79325703  1.42615987  0.53621547  0.09535141
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.10244, df1 = 1, df2 = 17, p-value = 0.7528
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.10287, df = 1, p-value = 0.7484
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.766, df = 6, p-value = 0.4499
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.93073, p-value = 0.09035
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.25054652227515
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.1804, df1 = 2, df2 = 19, p-value = 0.3287
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.042852 -0.015443 -0.004394  0.016695  0.059431
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0009724  0.0027351   0.356    0.726
# dfinco.t  2.5650030  0.3633964   7.058 5.77e-07 ***
# drpri.t   0.0341202  0.1382379   0.247    0.807
# dexpo.1  -0.0644002  0.1174693  -0.548    0.589
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02616 on 21 degrees of freedom
# Multiple R-squared:  0.8496,	Adjusted R-squared:  0.821
# F-statistic: 29.66 on 4 and 21 DF,  p-value: 2.274e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.2090581  0.3885582  0.1289411
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.0040899, df1 = 1, df2 = 17, p-value = 0.9498
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.0034063, df = 1, p-value = 0.9535
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 10.2, df = 6, p-value = 0.1165
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96013, p-value = 0.417
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.30160129045968
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.95842, df1 = 2, df2 = 19, p-value = 0.4013
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0279784 -0.0128314  0.0007527  0.0132237  0.0294333
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.05540    0.07302  -0.759   0.4564
# dinco.t  3.33137    0.25213  13.213 1.21e-11 ***
# drpri.t  0.19410    0.08469   2.292   0.0324 *
# dimpo.1 -0.15093    0.08039  -1.877   0.0744 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01717 on 21 degrees of freedom
# Multiple R-squared:  0.938,	Adjusted R-squared:  0.9262
# F-statistic: 79.43 on 4 and 21 DF,  p-value: 2.267e-12
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1
# -0.4792890  1.2355419  0.1143074
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 2.3143, df1 = 1, df2 = 16, p-value = 0.1477
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 1.599, df = 1, p-value = 0.2061
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.9369, df = 7, p-value = 0.787
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.94159, p-value = 0.1611
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.53251245034975
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.0244, df1 = 2, df2 = 18, p-value = 0.379
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.036954 -0.014765 -0.000274  0.010039  0.041979
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1      0.002521   0.001305   1.933   0.0676 .
# dfinco.t  3.063880   0.280789  10.912 7.15e-10 ***
# dfinco.1 -1.308244   0.701000  -1.866   0.0767 .
# drpri.t  -0.169904   0.172289  -0.986   0.3358
# dexpo.1   0.242605   0.196657   1.234   0.2316
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02246 on 20 degrees of freedom
# Multiple R-squared:  0.9333,	Adjusted R-squared:  0.9166
# F-statistic: 55.94 on 5 and 20 DF,  p-value: 4.527e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.1918277  0.7043635  0.0917034
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 2.1113, df1 = 1, df2 = 16, p-value = 0.1655
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 1.7726, df = 1, p-value = 0.1831
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 10.9, df = 7, p-value = 0.143
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.94732, p-value = 0.218
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 6.78856553805687
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.53989, df1 = 2, df2 = 18, p-value = 0.592
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.041514 -0.006168  0.004075  0.014441  0.045614
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.06400    0.01375  -4.655 0.000153 ***
# dinco.t  1.95313    0.22390   8.723 2.99e-08 ***
# dinco.1 -1.15959    0.40302  -2.877 0.009315 **
# drpri.t  0.05832    0.15332   0.380 0.707679
# dimpo.1  0.30538    0.15260   2.001 0.059123 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02068 on 20 degrees of freedom
# Multiple R-squared:  0.9257,	Adjusted R-squared:  0.9072
# F-statistic: 49.86 on 5 and 20 DF,  p-value: 1.305e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1
# -0.06326806  0.09989207 -0.24148992
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.41194, df1 = 1, df2 = 17, p-value = 0.5295
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.27201, df = 1, p-value = 0.602
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 6.1358, df = 6, p-value = 0.4081
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.95862, p-value = 0.3876
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.98589803968444
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 2.7501, df1 = 2, df2 = 19, p-value = 0.08934
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.10315 -0.03041 -0.01252  0.03158  0.11894
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.001687   0.001747  -0.966    0.345
# dfinco.t  4.220611   0.789806   5.344 2.67e-05 ***
# drpri.t  -0.159872   0.163596  -0.977    0.340
# dexpo.1  -0.016293   0.145165  -0.112    0.912
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06196 on 21 degrees of freedom
# Multiple R-squared:  0.6815,	Adjusted R-squared:  0.6209
# F-statistic: 11.23 on 4 and 21 DF,  p-value: 4.942e-05
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.4592267  1.2093168  0.2198231
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.029834, df1 = 1, df2 = 15, p-value = 0.8652
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.034186, df = 1, p-value = 0.8533
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 7.3931, df = 8, p-value = 0.4949
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.97631, p-value = 0.8037
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.41312371695516
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.43443, df1 = 2, df2 = 18, p-value = 0.6542
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.177492 -0.019010  0.005086  0.032762  0.101743
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.017887   0.013870  -1.290    0.212
# dinco.t  1.640131   0.320813   5.112 5.31e-05 ***
# drpri.t  0.139298   0.164589   0.846    0.407
# ddum.t   0.068986   0.066536   1.037    0.312
# ddum.1  -0.003874   0.066096  -0.059    0.954
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06432 on 20 degrees of freedom
# Multiple R-squared:  0.6439,	Adjusted R-squared:  0.5548
# F-statistic: 7.231 on 5 and 20 DF,  p-value: 0.0005183
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.30065999  0.18099594  0.42449217  0.05898003
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.018602, df1 = 1, df2 = 17, p-value = 0.8931
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.0060276, df = 1, p-value = 0.9381
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.6093, df = 6, p-value = 0.7294
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.86321, p-value = 0.003171
#
# The p-value of Shapiro-Wilk test normality of residuals:  0.003170772 < 0.05!
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 1.47517107283528
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 3.1046, df1 = 2, df2 = 19, p-value = 0.06813
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.093830 -0.047980 -0.008719  0.020287  0.197628
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0010422  0.0004267   2.443   0.0235 *
# dfinco.t  1.7394875  0.9269348   1.877   0.0745 .
# drpri.t  -0.4699181  0.2435175  -1.930   0.0673 .
# dexpo.1   0.1328554  0.1903638   0.698   0.4929
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0669 on 21 degrees of freedom
# Multiple R-squared:  0.7581,	Adjusted R-squared:  0.712
# F-statistic: 16.45 on 4 and 21 DF,  p-value: 3.025e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
#  0.01872390 -0.22924650 -0.05144336
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.31997, df1 = 1, df2 = 13, p-value = 0.5813
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.16205, df = 1, p-value = 0.6873
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.3007, df = 8, p-value = 0.725
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98316, p-value = 0.9523
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 4.57517592908376
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 4.5726, df1 = 2, df2 = 15, p-value = 0.02815
#
# the p-value of RESET test:  0.02814895 < 0.05!
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 4, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.091060 -0.008626  0.007449  0.041636  0.083492
#
# Coefficients:
#         Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.14605    0.09268  -1.576 0.133472
# dinco.t  1.06326    0.21137   5.030 0.000103 ***
# drpri.t -0.46706    0.29844  -1.565 0.136008
# dimpo.1  0.49309    0.16486   2.991 0.008209 **
# dimpo.2 -0.22219    0.19814  -1.121 0.277718
# dimpo.3 -0.02292    0.15909  -0.144 0.887127
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05194 on 17 degrees of freedom
# Multiple R-squared:  0.8619,	Adjusted R-squared:  0.8132
# F-statistic: 17.69 on 6 and 17 DF,  p-value: 1.881e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1
# -0.4569612  0.6950902 -0.3474241
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.53873, df1 = 1, df2 = 14, p-value = 0.4751
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.57679, df = 1, p-value = 0.4476
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 10.782, df = 8, p-value = 0.2144
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.95062, p-value = 0.2794
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 9.43772674116529
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 2.9932, df1 = 2, df2 = 16, p-value = 0.07865
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 3, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.045745 -0.017011 -0.003753  0.009345  0.070336
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1     -0.0008107  0.0025193  -0.322   0.7513
# dfinco.t  3.6187524  0.4533539   7.982 2.53e-07 ***
# dfinco.1 -2.0860134  0.7576708  -2.753   0.0131 *
# drpri.t  -0.2567201  0.3408929  -0.753   0.4611
# dexpo.1   0.3158563  0.2017574   1.566   0.1349
# dexpo.2   0.0108597  0.1092339   0.099   0.9219
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03079 on 18 degrees of freedom
# Multiple R-squared:  0.8393,	Adjusted R-squared:  0.7857
# F-statistic: 15.66 on 6 and 18 DF,  p-value: 2.884e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -1.0757805  2.1953147 -0.7648106
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.011634, df1 = 1, df2 = 14, p-value = 0.9156
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.01464, df = 1, p-value = 0.9037
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.0793, df = 9, p-value = 0.8273
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.93303, p-value = 0.1021
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.595660266867
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.16539, df1 = 2, df2 = 17, p-value = 0.8489
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.050679 -0.013079 -0.000971  0.013677  0.047045
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.010026   0.004853  -2.066   0.0527 .
# dinco.t  2.765774   0.290322   9.527 1.14e-08 ***
# drpri.t  0.227375   0.238514   0.953   0.3524
# drpri.1 -0.375594   0.214926  -1.748   0.0967 .
# ddum.t   0.014630   0.026992   0.542   0.5941
# ddum.1  -0.039809   0.026499  -1.502   0.1495
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02444 on 19 degrees of freedom
# Multiple R-squared:  0.8953,	Adjusted R-squared:  0.8623
# F-statistic: 27.09 on 6 and 19 DF,  p-value: 2.414e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.33551110  1.18010435 -0.25286394  0.07132027
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.052437, df1 = 1, df2 = 16, p-value = 0.8218
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.06662, df = 1, p-value = 0.7963
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.9065, df = 7, p-value = 0.5507
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96176, p-value = 0.4506
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.36112190216361
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 1.6119, df1 = 2, df2 = 18, p-value = 0.227
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034820 -0.011315  0.002573  0.011126  0.034232
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1      0.008393   0.002484   3.378  0.00299 **
# dfinco.t  2.325115   0.260600   8.922 2.08e-08 ***
# drpri.t   0.170780   0.155648   1.097  0.28558
# drpri.1   0.217266   0.163272   1.331  0.19826
# dexpo.1  -0.237810   0.105669  -2.251  0.03583 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02032 on 20 degrees of freedom
# Multiple R-squared:  0.9187,	Adjusted R-squared:  0.8983
# F-statistic: 45.18 on 5 and 20 DF,  p-value: 3.206e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
# -0.03057827  0.04009441 -0.10824942
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 6.198, df1 = 1, df2 = 13, p-value = 0.02712
#
# The p-value of Breusch-Godfrey test for the autocorrelation in residuals:  0.02711615 < 0.05!
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 4.4744, df = 1, p-value = 0.03441
#
# The p-value of Ljung-Box test for the autocorrelation in residuals:  0.03440689 < 0.05!
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 16.831, df = 10, p-value = 0.07819
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.95745, p-value = 0.366
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.2263760815202
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.28341, df1 = 2, df2 = 16, p-value = 0.7569
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.071072 -0.008487 -0.003797  0.004427  0.083990
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.0175843  0.0083858  -2.097   0.0504 .
# dinco.t  2.1721076  0.3853748   5.636 2.39e-05 ***
# dinco.1 -0.7393703  0.3997237  -1.850   0.0808 .
# drpri.t -0.0163824  0.2582295  -0.063   0.9501
# drpri.1  0.0203725  0.3068428   0.066   0.9478
# ddum.t   0.0003541  0.0398629   0.009   0.9930
# ddum.1  -0.0491139  0.0335882  -1.462   0.1609
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03136 on 18 degrees of freedom
# Multiple R-squared:  0.847,	Adjusted R-squared:  0.7875
# F-statistic: 14.24 on 7 and 18 DF,  p-value: 3.596e-06
#
# ------------------------------------------------------
# Long-run coefficients:
#     impo.1     inco.1     rpri.1      dum.1
# -0.3302606  0.5723346  0.3272584  0.0820918
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.0040176, df1 = 1, df2 = 16, p-value = 0.9502
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.0023628, df = 1, p-value = 0.9612
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 3.4294, df = 7, p-value = 0.8426
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96969, p-value = 0.6371
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.62013917674288
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.51092, df1 = 2, df2 = 18, p-value = 0.6084
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04134 -0.01041  0.00209  0.01099  0.06301
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# ec.1      0.0022602  0.0007897   2.862  0.00964 **
# dfinco.t  2.4054645  0.3283676   7.326 4.42e-07 ***
# dfinco.1 -1.3714366  0.4791514  -2.862  0.00963 **
# drpri.t  -0.4681398  0.2262060  -2.070  0.05166 .
# dexpo.1   0.2013032  0.1770576   1.137  0.26900
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02554 on 20 degrees of freedom
# Multiple R-squared:  0.8875,	Adjusted R-squared:  0.8594
# F-statistic: 31.55 on 5 and 20 DF,  p-value: 7.841e-09
#
# ------------------------------------------------------
# Long-run coefficients:
#     expo.1    finco.1     rpri.1
# -0.1091053  0.3068078 -0.3181322
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.13596, df1 = 1, df2 = 16, p-value = 0.7172
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.12579, df = 1, p-value = 0.7228
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.5972, df = 7, p-value = 0.5875
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.98348, p-value = 0.9442
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 3.32061386851097
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.1623, df1 = 2, df2 = 18, p-value = 0.8514
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.043170 -0.011964  0.001747  0.012805  0.035821
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1    -0.032957   0.009435  -3.493 0.002292 **
# dinco.t  2.827628   0.273347  10.344 1.78e-09 ***
# dinco.1 -1.647381   0.366958  -4.489 0.000224 ***
# drpri.t -0.296661   0.198192  -1.497 0.150052
# dimpo.1  0.176827   0.138946   1.273 0.217745
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02058 on 20 degrees of freedom
# Multiple R-squared:  0.9316,	Adjusted R-squared:  0.9145
# F-statistic: 54.49 on 5 and 20 DF,  p-value: 5.763e-11
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1
# -0.04687273  0.10849520 -0.27414660
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 0.14889, df1 = 1, df2 = 16, p-value = 0.7047
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 0.058899, df = 1, p-value = 0.8082
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 6.1232, df = 7, p-value = 0.5254
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.96289, p-value = 0.4751
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 2
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.915            3.695
#  5% critical value        3.538            4.428
#  1% critical value        5.155            6.265
#
#
#  F-statistic = 2.08057552796928
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 0.21718, df1 = 2, df2 = 18, p-value = 0.8069
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03513 -0.01657  0.00170  0.01284  0.03669
#
# Coefficients:
#           Estimate Std. Error t value Pr(>|t|)
# ec.1      0.003347   0.002104   1.591 0.127301
# dfinco.t  2.420066   0.319948   7.564 2.74e-07 ***
# dfinco.1 -2.101528   0.398973  -5.267 3.73e-05 ***
# drpri.t   0.013296   0.162952   0.082 0.935781
# dexpo.1   0.592136   0.134000   4.419 0.000264 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02288 on 20 degrees of freedom
# Multiple R-squared:  0.9209,	Adjusted R-squared:  0.9011
# F-statistic: 46.55 on 5 and 20 DF,  p-value: 2.44e-10
#
# ------------------------------------------------------
# Long-run coefficients:
#      expo.1     finco.1      rpri.1
# -0.11826536  0.19257822 -0.08428204
#
#
#  Breusch-Godfrey Test for the autocorrelation in residuals:
#
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  modelFull$model
# LM test = 1.1484, df1 = 1, df2 = 13, p-value = 0.3034
#
# ------------------------------------------------------
#
#  Ljung-Box Test for the autocorrelation in residuals:
#
# 	Box-Ljung test
#
# data:  res
# X-squared = 1.3734, df = 1, p-value = 0.2412
#
# ------------------------------------------------------
#
#  Breusch-Pagan Test for the homoskedasticity of residuals:
#
# 	studentized Breusch-Pagan test
#
# data:  modelFull$model
# BP = 5.8918, df = 10, p-value = 0.8243
#
# ------------------------------------------------------
#
#  Shapiro-Wilk test of normality of residuals:
#
# 	Shapiro-Wilk normality test
#
# data:  modelFull$model$residual
# W = 0.97772, p-value = 0.8365
#
# ------------------------------------------------------
#
#  PESARAN, SHIN AND SMITH (2001) COINTEGRATION TEST
#
#  Observations: 26
#  Number of Regressors (k): 3
#  Case: 2
#
#  ------------------------------------------------------
#  -                       F-test                       -
#  ------------------------------------------------------
#                  <------- I(0) ------------ I(1) ----->
#  10% critical value       2.676            3.586
#  5% critical value        3.272            4.306
#  1% critical value        4.614            5.966
#
#
#  F-statistic = 2.92520381373836
#
#  ------------------------------------------------------
#
#
# ------------------------------------------------------
#
#  Ramsey's RESET Test for model specification:
#
# 	RESET test
#
# data:  modelECM$model
# RESET = 3.5967, df1 = 2, df2 = 16, p-value = 0.05129
#
# ------------------------------------------------------
# ------------------------------------------------------
# Error Correction Model Output:
#
# Time series regression with "ts" data:
# Start = 2, End = 26
#
# Call:
# dynlm(formula = as.formula(model.text), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07258 -0.01098  0.00000  0.01995  0.03346
#
# Coefficients:
#          Estimate Std. Error t value Pr(>|t|)
# ec.1     0.001542   0.013879   0.111 0.912763
# dinco.t  3.714349   0.417723   8.892 5.27e-08 ***
# dinco.1 -2.302709   0.526016  -4.378 0.000363 ***
# drpri.t -0.117690   0.222333  -0.529 0.603038
# ddum.t   0.022974   0.030875   0.744 0.466417
# ddum.1  -0.033274   0.030469  -1.092 0.289207
# dimpo.1  0.253572   0.143997   1.761 0.095224 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02848 on 18 degrees of freedom
# Multiple R-squared:  0.9189,	Adjusted R-squared:  0.8874
# F-statistic: 29.15 on 7 and 18 DF,  p-value: 1.42e-08
#
# ------------------------------------------------------
# Long-run coefficients:
#      impo.1      inco.1      rpri.1       dum.1
# -0.40327445  0.90419188  0.05643735 -0.05254866
#
#     ardl_fx ardl_fx1 X1 X2 X3  ardl_fm  ardl_fm1 X1 X2 X3
# 1  1.806515 1.642668  1  1  0 2.152142 1.3252669  1  0  0
# 2  1.312005 1.168245  1  0  0 3.669701 1.2891705  1  1  0
# 3  2.934790 2.934790  2  0  1 2.814153 0.3775809  0  0  0
# 4  3.250547 1.779624  1  0  0 2.301601 3.2505465  1  0  0
# 5  2.532512 2.536138  1  1  0 6.788566 2.5325125  1  1  0
# 6  1.985898 1.985898  1  0  0 2.413124 2.7224007  0  0  0
# 7  1.475171 1.281960  1  0  0 4.575176 1.0299834  3  0  0
# 8  9.437727 9.437727  2  1  0 2.595660 6.3539250  0  0  1
# 9  3.361122 3.361122  1  0  1 2.226376 5.8486318  0  1  1
# 10 2.620139 2.464938  1  1  0 3.320614 2.6201392  1  1  0
# 11 2.080576 2.080576  1  1  0 2.925204 4.4821140  1  1  0
